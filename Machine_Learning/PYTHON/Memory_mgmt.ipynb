# %%
import sys

a=[]
print(sys.getrefcount(a)) 
# returns 2 - 1 from var. a and 1 from funcn
# Out:
# 2

# %%
b=a
print(sys.getrefcount(b))
# returns 3 - 2 from a 1 from b var.
# Out:
# 3

# %%
import gc

#enable garbage collection.
gc.enable()

# %%
gc.disable()

# %%
gc.collect() # runs the garbage collector
# Out:
# 1029

# %%
gc.get_stats()
# Out:
# [{'collections': 75, 'collected': 1574, 'uncollectable': 0},
#  {'collections': 6, 'collected': 390, 'uncollectable': 0},
#  {'collections': 1, 'collected': 1029, 'uncollectable': 0}]

# %%
gc.garbage
# Out:
# []

# %%
import gc

class MyObject:
    def __init__(self,name):
        self.name = name
        print(f"Object {self.name} created. !!")
    
    def __del__(self):
        print(f"Object {self.name} deleted. !!")
      
# Creating Circular reference      
  
obj1 = MyObject("obj1")
obj2 = MyObject("obj2")
obj1.ref = obj2
obj2.ref = obj1

del obj1
del obj2

# here this won't trigger gc , as they are circular references, so here, we'll have to manually manage GC.

gc.collect()
# Out:
# Object obj1 created. !!
# Object obj2 created. !!
# Object obj1 deleted. !!
# Object obj2 deleted. !!
# Object obj1 deleted. !!
# Object obj2 deleted. !!
# 4100

# %%
()
