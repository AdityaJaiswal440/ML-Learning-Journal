# %%
import pandas as pd

# %%
# A pandas series is a 1-D array like obj, that can hold any data type.It is similar to a column in table

# %%
import numpy as np
data = np.arange(1,6)
series=pd.Series(data)
print("Series \n",series)
# Out:
# Series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# Series comes w default indexes

# %%
print(type(series))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data = {
    'a' : 1,
    'b' : 2,
    'c' : 3
}
dict_series = pd.Series(data)
print(dict_series)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = np.arange(10,31,10)
ind = ['a','b','c']
series = pd.Series(data,index=ind)
print(series)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
import pandas as pd

# Creating a Series
ages = pd.Series([20, 21, 19], name="Age")
print(ages)
# Out:
# 0    20
# 1    21
# 2    19
# Name: Age, dtype: int64

# %%
data = {
    "Name": ["Aditya", "Abhay", "Rahul"],
    "Age": [20, 21, 19],
    "Branch": ["AI & DS", "AI & DS", "CS"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age   Branch
# 0  Aditya   20  AI & DS
# 1   Abhay   21  AI & DS
# 2   Rahul   19       CS

# %%
data = {
    "Name": ["Aditya", "Abhay", "Rahul"],
    "Age": [20, 21, 19],
    "Branch": ["AI & DS", "AI & DS", "CS"]
}
df = pd.DataFrame(data,index=ind)
print(df)
# Out:
#      Name  Age   Branch
# a  Aditya   20  AI & DS
# b   Abhay   21  AI & DS
# c   Rahul   19       CS

# %%
data = [
    {'Name':'Krish','Age':32,'City':'Delhi'},
    {'Name':'Jack','Age':31,'City':'Mumbai'},
    {'Name':'Rocky','Age':37,'City':'Chennai'},
    {'Name':'Joy','Age':39,'City':'California'}
]
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age        City
# 0  Krish   32       Delhi
# 1   Jack   31      Mumbai
# 2  Rocky   37     Chennai
# 3    Joy   39  California

# %%
df = pd.read_csv('Practice.csv')
df.head()
# Out:
#   customer_id  gender  age     country      city customer_segment  \
# 0  CUST_00001    Male   68  Bangladesh    London              SME
# 1  CUST_00002  Female   57      Canada    Sydney       Individual
# 2  CUST_00003    Male   24     Germany  New York              SME
# 3  CUST_00004    Male   49   Australia     Dhaka       Individual
# 4  CUST_00005    Male   65  Bangladesh     Delhi       Individual
#
#    tenure_months signup_channel contract_type  monthly_logins  ...  \
# 0             22            Web       Monthly              26  ...
# 1              9         Mobile       Monthly               7  ...
# 2             58            Web        Yearly              19  ...
# 3             19         Mobile        Yearly              34  ...
# 4             52            Web       Monthly              20  ...
#
#    avg_resolution_time  complaint_type  csat_score  escalations  \
# 0            13.354360         Service         4.0            0
# ...

# %%
df.tail()
# Out:
#      customer_id  gender  age  country     city customer_segment  \
# 9995  CUST_09996  Female   67  Germany   Sydney              SME
# 9996  CUST_09997    Male   26      USA  Toronto       Individual
# 9997  CUST_09998  Female   18   Canada   Sydney       Individual
# 9998  CUST_09999  Female   30      USA    Delhi       Individual
# 9999  CUST_10000    Male   67       UK   Berlin              SME
#
#       tenure_months signup_channel contract_type  monthly_logins  ...  \
# 9995             37            Web        Yearly              15  ...
# 9996             42         Mobile        Yearly              13  ...
# 9997             39         Mobile        Yearly              15  ...
# 9998             52            Web       Monthly              14  ...
# 9999              7         Mobile       Monthly              15  ...
#
#       avg_resolution_time  complaint_type  csat_score  escalations  \
# 9995            34.240174         Service         4.0            1
# ...

# %%
df
# Out:
#      customer_id  gender  age     country      city customer_segment  \
# 0     CUST_00001    Male   68  Bangladesh    London              SME
# 1     CUST_00002  Female   57      Canada    Sydney       Individual
# 2     CUST_00003    Male   24     Germany  New York              SME
# 3     CUST_00004    Male   49   Australia     Dhaka       Individual
# 4     CUST_00005    Male   65  Bangladesh     Delhi       Individual
# ...          ...     ...  ...         ...       ...              ...
# 9995  CUST_09996  Female   67     Germany    Sydney              SME
# 9996  CUST_09997    Male   26         USA   Toronto       Individual
# 9997  CUST_09998  Female   18      Canada    Sydney       Individual
# 9998  CUST_09999  Female   30         USA     Delhi       Individual
# 9999  CUST_10000    Male   67          UK    Berlin              SME
#
#       tenure_months signup_channel contract_type  monthly_logins  ...  \
# ...

# %%
print(data)
# Out:
# [{'Name': 'Krish', 'Age': 32, 'City': 'Delhi'}, {'Name': 'Jack', 'Age': 31, 'City': 'Mumbai'}, {'Name': 'Rocky', 'Age': 37, 'City': 'Chennai'}, {'Name': 'Joy', 'Age': 39, 'City': 'California'}]

# %%
df
# Out:
#      customer_id  gender  age     country      city customer_segment  \
# 0     CUST_00001    Male   68  Bangladesh    London              SME
# 1     CUST_00002  Female   57      Canada    Sydney       Individual
# 2     CUST_00003    Male   24     Germany  New York              SME
# 3     CUST_00004    Male   49   Australia     Dhaka       Individual
# 4     CUST_00005    Male   65  Bangladesh     Delhi       Individual
# ...          ...     ...  ...         ...       ...              ...
# 9995  CUST_09996  Female   67     Germany    Sydney              SME
# 9996  CUST_09997    Male   26         USA   Toronto       Individual
# 9997  CUST_09998  Female   18      Canada    Sydney       Individual
# 9998  CUST_09999  Female   30         USA     Delhi       Individual
# 9999  CUST_10000    Male   67          UK    Berlin              SME
#
#       tenure_months signup_channel contract_type  monthly_logins  ...  \
# ...

# %%
df =pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age        City
# 0  Krish   32       Delhi
# 1   Jack   31      Mumbai
# 2  Rocky   37     Chennai
# 3    Joy   39  California

# %%
df.loc[0]
# Out:
# Name    Krish
# Age        32
# City    Delhi
# Name: 0, dtype: object

# %%
df.loc[1]
# Out:
# Name      Jack
# Age         31
# City    Mumbai
# Name: 1, dtype: object

# %%
print(df.iloc[0][1])
# Out:
# 32
# C:\Users\jaisw\AppData\Local\Temp\ipykernel_23596\134252878.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df.iloc[0][1])

# %%
df.iloc[1]
# Out:
# Name      Jack
# Age         31
# City    Mumbai
# Name: 1, dtype: object

# %%
df
# Out:
#     Name  Age        City
# 0  Krish   32       Delhi
# 1   Jack   31      Mumbai
# 2  Rocky   37     Chennai
# 3    Joy   39  California

# %%
df.at[1,'Name']
# Out:
# 'Jack'

# %%
print(df.at[2,'Age'])
# Out:
# 37

# %%
df.iat[2,2]
# Out:
# 'Chennai'

# %%
df['Salary'] = ['50k','60k','70k','80k']

# %%
df
# Out:
#     Name  Age        City Salary
# 0  Krish   32       Delhi    50k
# 1   Jack   31      Mumbai    60k
# 2  Rocky   37     Chennai    70k
# 3    Joy   39  California    80k

# %%
df.drop('Salary',axis=1)
# Out:
#     Name  Age        City
# 0  Krish   32       Delhi
# 1   Jack   31      Mumbai
# 2  Rocky   37     Chennai
# 3    Joy   39  California

# %%
df
# Out:
#     Name  Age        City Salary
# 0  Krish   32       Delhi    50k
# 1   Jack   31      Mumbai    60k
# 2  Rocky   37     Chennai    70k
# 3    Joy   39  California    80k

# %%
df.drop('Salary',axis=1,inplace=True)

# %%
df
# Out:
#     Name  Age        City
# 0  Krish   32       Delhi
# 1   Jack   31      Mumbai
# 2  Rocky   37     Chennai
# 3    Joy   39  California

# %%
df.loc[len(df)] = ['David',29,'New York']

# %%
df
# Out:
#     Name  Age        City
# 0  Krish   32       Delhi
# 1   Jack   31      Mumbai
# 2  Rocky   37     Chennai
# 3    Joy   39  California
# 4  David   29    New York

# %%
df.drop(1,inplace=True)

# %%
df
# Out:
#     Name  Age        City
# 2  Rocky   37     Chennai
# 3    Joy   39  California

# %%
df= pd.read_csv('Practice.csv')
df.head()
# Out:
#   customer_id  gender  age     country      city customer_segment  \
# 0  CUST_00001    Male   68  Bangladesh    London              SME
# 1  CUST_00002  Female   57      Canada    Sydney       Individual
# 2  CUST_00003    Male   24     Germany  New York              SME
# 3  CUST_00004    Male   49   Australia     Dhaka       Individual
# 4  CUST_00005    Male   65  Bangladesh     Delhi       Individual
#
#    tenure_months signup_channel contract_type  monthly_logins  ...  \
# 0             22            Web       Monthly              26  ...
# 1              9         Mobile       Monthly               7  ...
# 2             58            Web        Yearly              19  ...
# 3             19         Mobile        Yearly              34  ...
# 4             52            Web       Monthly              20  ...
#
#    avg_resolution_time  complaint_type  csat_score  escalations  \
# 0            13.354360         Service         4.0            0
# ...

# %%
print(df.columns)
# Out:
# Index(['customer_id', 'gender', 'age', 'country', 'city', 'customer_segment',
#        'tenure_months', 'signup_channel', 'contract_type', 'monthly_logins',
#        'weekly_active_days', 'avg_session_time', 'features_used',
#        'usage_growth_rate', 'last_login_days_ago', 'monthly_fee',
#        'total_revenue', 'payment_method', 'payment_failures',
#        'discount_applied', 'price_increase_last_3m', 'support_tickets',
#        'avg_resolution_time', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'churn'],
#       dtype='object')

# %%
df = pd.read_csv('Practice.csv')

# %%
df.head()
# Out:
#   customer_id  gender  age     country      city customer_segment  \
# 0  CUST_00001    Male   68  Bangladesh    London              SME
# 1  CUST_00002  Female   57      Canada    Sydney       Individual
# 2  CUST_00003    Male   24     Germany  New York              SME
# 3  CUST_00004    Male   49   Australia     Dhaka       Individual
# 4  CUST_00005    Male   65  Bangladesh     Delhi       Individual
#
#    tenure_months signup_channel contract_type  monthly_logins  ...  \
# 0             22            Web       Monthly              26  ...
# 1              9         Mobile       Monthly               7  ...
# 2             58            Web        Yearly              19  ...
# 3             19         Mobile        Yearly              34  ...
# 4             52            Web       Monthly              20  ...
#
#    avg_resolution_time  complaint_type  csat_score  escalations  \
# 0            13.354360         Service         4.0            0
# ...

# %%
df.tail()
# Out:
#      customer_id  gender  age  country     city customer_segment  \
# 9995  CUST_09996  Female   67  Germany   Sydney              SME
# 9996  CUST_09997    Male   26      USA  Toronto       Individual
# 9997  CUST_09998  Female   18   Canada   Sydney       Individual
# 9998  CUST_09999  Female   30      USA    Delhi       Individual
# 9999  CUST_10000    Male   67       UK   Berlin              SME
#
#       tenure_months signup_channel contract_type  monthly_logins  ...  \
# 9995             37            Web        Yearly              15  ...
# 9996             42         Mobile        Yearly              13  ...
# 9997             39         Mobile        Yearly              15  ...
# 9998             52            Web       Monthly              14  ...
# 9999              7         Mobile       Monthly              15  ...
#
#       avg_resolution_time  complaint_type  csat_score  escalations  \
# 9995            34.240174         Service         4.0            1
# ...

# %%
df.head()
# Out:
#   customer_id  gender  age     country      city customer_segment  \
# 0  CUST_00001    Male   68  Bangladesh    London              SME
# 1  CUST_00002  Female   57      Canada    Sydney       Individual
# 2  CUST_00003    Male   24     Germany  New York              SME
# 3  CUST_00004    Male   49   Australia     Dhaka       Individual
# 4  CUST_00005    Male   65  Bangladesh     Delhi       Individual
#
#    tenure_months signup_channel contract_type  monthly_logins  ...  \
# 0             22            Web       Monthly              26  ...
# 1              9         Mobile       Monthly               7  ...
# 2             58            Web        Yearly              19  ...
# 3             19         Mobile        Yearly              34  ...
# 4             52            Web       Monthly              20  ...
#
#    avg_resolution_time  complaint_type  csat_score  escalations  \
# 0            13.354360         Service         4.0            0
# ...

# %%
df.describe()
# Out:
#                 age  tenure_months  monthly_logins  weekly_active_days  \
# count  10000.000000   10000.000000    10000.000000        10000.000000
# mean      45.906100      30.155700       19.672000            3.479400
# std       16.420416      17.099517        9.838003            2.302283
# min       18.000000       1.000000        0.000000            0.000000
# 25%       32.000000      16.000000       13.000000            1.000000
# 50%       46.000000      30.000000       20.000000            3.000000
# 75%       60.000000      45.000000       26.000000            5.000000
# max       74.000000      59.000000       54.000000            7.000000
#
#        avg_session_time  features_used  usage_growth_rate  \
# count      10000.000000   10000.000000       10000.000000
# mean          15.187890       4.990800           0.019423
# std            6.830774       2.211607           0.149567
# min            1.000000       1.000000          -0.580000
# ...

# %%
df.head().dtypes
# Out:
# customer_id                object
# gender                     object
# age                         int64
# country                    object
# city                       object
# customer_segment           object
# tenure_months               int64
# signup_channel             object
# contract_type              object
# monthly_logins              int64
# weekly_active_days          int64
# avg_session_time          float64
# features_used               int64
# usage_growth_rate         float64
# last_login_days_ago         int64
# monthly_fee                 int64
# total_revenue               int64
# payment_method             object
# payment_failures            int64
# discount_applied           object
# price_increase_last_3m     object
# support_tickets             int64
# avg_resolution_time       float64
# complaint_type             object
# csat_score                float64
# escalations                 int64
# email_open_rate           float64
# ...

# %%
df.isnull()
# Out:
#       customer_id  gender    age  country   city  customer_segment  \
# 0           False   False  False    False  False             False
# 1           False   False  False    False  False             False
# 2           False   False  False    False  False             False
# 3           False   False  False    False  False             False
# 4           False   False  False    False  False             False
# ...           ...     ...    ...      ...    ...               ...
# 9995        False   False  False    False  False             False
# 9996        False   False  False    False  False             False
# 9997        False   False  False    False  False             False
# 9998        False   False  False    False  False             False
# 9999        False   False  False    False  False             False
#
#       tenure_months  signup_channel  contract_type  monthly_logins  ...  \
# 0             False           False          False           False  ...
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                  0
# gender                       0
# age                          0
# country                      0
# city                         0
# customer_segment             0
# tenure_months                0
# signup_channel               0
# contract_type                0
# monthly_logins               0
# weekly_active_days           0
# avg_session_time             0
# features_used                0
# usage_growth_rate            0
# last_login_days_ago          0
# monthly_fee                  0
# total_revenue                0
# payment_method               0
# payment_failures             0
# discount_applied             0
# price_increase_last_3m       0
# support_tickets              0
# avg_resolution_time          0
# complaint_type            2045
# csat_score                   0
# escalations                  0
# email_open_rate              0
# marketing_click_rate         0
# nps_score                    0
# survey_response              0
# ...

# %%
df[df.isnull()]
# Out:
#      customer_id gender  age country city customer_segment  tenure_months  \
# 0            NaN    NaN  NaN     NaN  NaN              NaN            NaN
# 1            NaN    NaN  NaN     NaN  NaN              NaN            NaN
# 2            NaN    NaN  NaN     NaN  NaN              NaN            NaN
# 3            NaN    NaN  NaN     NaN  NaN              NaN            NaN
# 4            NaN    NaN  NaN     NaN  NaN              NaN            NaN
# ...          ...    ...  ...     ...  ...              ...            ...
# 9995         NaN    NaN  NaN     NaN  NaN              NaN            NaN
# 9996         NaN    NaN  NaN     NaN  NaN              NaN            NaN
# 9997         NaN    NaN  NaN     NaN  NaN              NaN            NaN
# 9998         NaN    NaN  NaN     NaN  NaN              NaN            NaN
# 9999         NaN    NaN  NaN     NaN  NaN              NaN            NaN
#
#      signup_channel contract_type  monthly_logins  ...  avg_resolution_time  \
# ...

# %%
df.isnull().any(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998     True
# 9999    False
# Length: 10000, dtype: bool

# %%
df.isnull().any()
# Out:
# customer_id               False
# gender                    False
# age                       False
# country                   False
# city                      False
# customer_segment          False
# tenure_months             False
# signup_channel            False
# contract_type             False
# monthly_logins            False
# weekly_active_days        False
# avg_session_time          False
# features_used             False
# usage_growth_rate         False
# last_login_days_ago       False
# monthly_fee               False
# total_revenue             False
# payment_method            False
# payment_failures          False
# discount_applied          False
# price_increase_last_3m    False
# support_tickets           False
# avg_resolution_time       False
# complaint_type             True
# csat_score                False
# escalations               False
# email_open_rate           False
# marketing_click_rate      False
# nps_score                 False
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                  0
# gender                       0
# age                          0
# country                      0
# city                         0
# customer_segment             0
# tenure_months                0
# signup_channel               0
# contract_type                0
# monthly_logins               0
# weekly_active_days           0
# avg_session_time             0
# features_used                0
# usage_growth_rate            0
# last_login_days_ago          0
# monthly_fee                  0
# total_revenue                0
# payment_method               0
# payment_failures             0
# discount_applied             0
# price_increase_last_3m       0
# support_tickets              0
# avg_resolution_time          0
# complaint_type            2045
# csat_score                   0
# escalations                  0
# email_open_rate              0
# marketing_click_rate         0
# nps_score                    0
# survey_response              0
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'country', 'city', 'customer_segment',
#        'tenure_months', 'signup_channel', 'contract_type', 'monthly_logins',
#        'weekly_active_days', 'avg_session_time', 'features_used',
#        'usage_growth_rate', 'last_login_days_ago', 'monthly_fee',
#        'total_revenue', 'payment_method', 'payment_failures',
#        'discount_applied', 'price_increase_last_3m', 'support_tickets',
#        'avg_resolution_time', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'churn'],
#       dtype='object')

# %%
df.iloc[['escalations','email_open_rate', 'marketing_click_rate']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23596\1874007448.py in ?()
# ----> 1 df.iloc[['escalations','email_open_rate', 'marketing_click_rate']]
#
# c:\Users\jaisw\anaconda3\Lib\site-packages\pandas\core\indexing.py in ?(self, key)
#    1188             axis = self.axis or 0
#    1189
#    1190             maybe_callable = com.apply_if_callable(key, self.obj)
#    1191             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192             return self._getitem_axis(maybe_callable, axis=axis)
#
# c:\Users\jaisw\anaconda3\Lib\site-packages\pandas\core\indexing.py in ?(self, key, axis)
#    1740             return self._getbool_axis(key, axis=axis)
#    1741
#    1742         # a list of integers
#    1743         elif is_list_like_indexer(key):
# ...

# %%
x=df[df['escalations'].isnull()]
x
# Out:
# Empty DataFrame
# Columns: [customer_id, gender, age, country, city, customer_segment, tenure_months, signup_channel, contract_type, monthly_logins, weekly_active_days, avg_session_time, features_used, usage_growth_rate, last_login_days_ago, monthly_fee, total_revenue, payment_method, payment_failures, discount_applied, price_increase_last_3m, support_tickets, avg_resolution_time, complaint_type, csat_score, escalations, email_open_rate, marketing_click_rate, nps_score, survey_response, referral_count, churn]
# Index: []
#
# [0 rows x 32 columns]

# %%
target_cols = [ 'escalations','email_open_rate', 'marketing_click_rate']

missing_any = df[df[target_cols].any(axis=1)]
print(missing_any)
# Out:
#      customer_id  gender  age     country      city customer_segment  \
# 0     CUST_00001    Male   68  Bangladesh    London              SME
# 1     CUST_00002  Female   57      Canada    Sydney       Individual
# 2     CUST_00003    Male   24     Germany  New York              SME
# 3     CUST_00004    Male   49   Australia     Dhaka       Individual
# 4     CUST_00005    Male   65  Bangladesh     Delhi       Individual
# ...          ...     ...  ...         ...       ...              ...
# 9995  CUST_09996  Female   67     Germany    Sydney              SME
# 9996  CUST_09997    Male   26         USA   Toronto       Individual
# 9997  CUST_09998  Female   18      Canada    Sydney       Individual
# 9998  CUST_09999  Female   30         USA     Delhi       Individual
# 9999  CUST_10000    Male   67          UK    Berlin              SME
#
#       tenure_months signup_channel contract_type  monthly_logins  ...  \
# ...

# %%
df.isnull()
# Out:
#       customer_id  gender    age  country   city  customer_segment  \
# 0           False   False  False    False  False             False
# 1           False   False  False    False  False             False
# 2           False   False  False    False  False             False
# 3           False   False  False    False  False             False
# 4           False   False  False    False  False             False
# ...           ...     ...    ...      ...    ...               ...
# 9995        False   False  False    False  False             False
# 9996        False   False  False    False  False             False
# 9997        False   False  False    False  False             False
# 9998        False   False  False    False  False             False
# 9999        False   False  False    False  False             False
#
#       tenure_months  signup_channel  contract_type  monthly_logins  ...  \
# 0             False           False          False           False  ...
# ...

# %%
df.isnull().any()
# Out:
# customer_id               False
# gender                    False
# age                       False
# country                   False
# city                      False
# customer_segment          False
# tenure_months             False
# signup_channel            False
# contract_type             False
# monthly_logins            False
# weekly_active_days        False
# avg_session_time          False
# features_used             False
# usage_growth_rate         False
# last_login_days_ago       False
# monthly_fee               False
# total_revenue             False
# payment_method            False
# payment_failures          False
# discount_applied          False
# price_increase_last_3m    False
# support_tickets           False
# avg_resolution_time       False
# complaint_type             True
# csat_score                False
# escalations               False
# email_open_rate           False
# marketing_click_rate      False
# nps_score                 False
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                  0
# gender                       0
# age                          0
# country                      0
# city                         0
# customer_segment             0
# tenure_months                0
# signup_channel               0
# contract_type                0
# monthly_logins               0
# weekly_active_days           0
# avg_session_time             0
# features_used                0
# usage_growth_rate            0
# last_login_days_ago          0
# monthly_fee                  0
# total_revenue                0
# payment_method               0
# payment_failures             0
# discount_applied             0
# price_increase_last_3m       0
# support_tickets              0
# avg_resolution_time          0
# complaint_type            2045
# csat_score                   0
# escalations                  0
# email_open_rate              0
# marketing_click_rate         0
# nps_score                    0
# survey_response              0
# ...

# %%
df_filled = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# customer_id                  0
# gender                       0
# age                          0
# country                      0
# city                         0
# customer_segment             0
# tenure_months                0
# signup_channel               0
# contract_type                0
# monthly_logins               0
# weekly_active_days           0
# avg_session_time             0
# features_used                0
# usage_growth_rate            0
# last_login_days_ago          0
# monthly_fee                  0
# total_revenue                0
# payment_method               0
# payment_failures             0
# discount_applied             0
# price_increase_last_3m       0
# support_tickets              0
# avg_resolution_time          0
# complaint_type            2045
# csat_score                   0
# escalations                  0
# email_open_rate              0
# marketing_click_rate         0
# nps_score                    0
# survey_response              0
# ...

# %%
print(df['complaint_type'].dtype)
# Out:
# object

# %%
df['complaint_type'] = df['complaint_type'].fillna(df['complaint_type'].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 df['complaint_type'] = df['complaint_type'].fillna(df['complaint_type'].mean())
#
# File c:\Users\jaisw\anaconda3\Lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\jaisw\anaconda3\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
# ...

# %%
df['complaint_type'] = df['complaint_type'].fillna(df['complaint_type'].mode()[0])

# %%
df.isnull().sum()
# Out:
# customer_id               0
# gender                    0
# age                       0
# country                   0
# city                      0
# customer_segment          0
# tenure_months             0
# signup_channel            0
# contract_type             0
# monthly_logins            0
# weekly_active_days        0
# avg_session_time          0
# features_used             0
# usage_growth_rate         0
# last_login_days_ago       0
# monthly_fee               0
# total_revenue             0
# payment_method            0
# payment_failures          0
# discount_applied          0
# price_increase_last_3m    0
# support_tickets           0
# avg_resolution_time       0
# complaint_type            0
# csat_score                0
# escalations               0
# email_open_rate           0
# marketing_click_rate      0
# nps_score                 0
# survey_response           0
# referral_count            0
# churn                     0
# dtype: int64

# %%
df=df.rename(columns={'customer_id':'CustomerID'})
df.head()
# Out:
#   Customer-ID  gender  age     country      city customer_segment  \
# 0  CUST_00001    Male   68  Bangladesh    London              SME
# 1  CUST_00002  Female   57      Canada    Sydney       Individual
# 2  CUST_00003    Male   24     Germany  New York              SME
# 3  CUST_00004    Male   49   Australia     Dhaka       Individual
# 4  CUST_00005    Male   65  Bangladesh     Delhi       Individual
#
#    tenure_months signup_channel contract_type  monthly_logins  ...  \
# 0             22            Web       Monthly              26  ...
# 1              9         Mobile       Monthly               7  ...
# 2             58            Web        Yearly              19  ...
# 3             19         Mobile        Yearly              34  ...
# 4             52            Web       Monthly              20  ...
#
#    avg_resolution_time  complaint_type  csat_score  escalations  \
# 0            13.354360         Service         4.0            0
# ...

# %%
df.dtypes
# Out:
# Customer-ID                object
# gender                     object
# age                         int64
# country                    object
# city                       object
# customer_segment           object
# tenure_months               int64
# signup_channel             object
# contract_type              object
# monthly_logins              int64
# weekly_active_days          int64
# avg_session_time          float64
# features_used               int64
# usage_growth_rate         float64
# last_login_days_ago         int64
# monthly_fee                 int64
# total_revenue               int64
# payment_method             object
# payment_failures            int64
# discount_applied           object
# price_increase_last_3m     object
# support_tickets             int64
# avg_resolution_time       float64
# complaint_type             object
# csat_score                float64
# escalations                 int64
# email_open_rate           float64
# ...

# %%
df = df.drop('support_tickets',axis=1)
df.dtypes
# Out:
# Customer-ID                object
# gender                     object
# age                         int64
# country                    object
# city                       object
# customer_segment           object
# tenure_months               int64
# signup_channel             object
# contract_type              object
# monthly_logins              int64
# weekly_active_days          int64
# avg_session_time          float64
# features_used               int64
# usage_growth_rate         float64
# last_login_days_ago         int64
# monthly_fee                 int64
# total_revenue               int64
# payment_method             object
# discount_applied           object
# price_increase_last_3m     object
# avg_resolution_time       float64
# complaint_type             object
# csat_score                float64
# escalations                 int64
# email_open_rate           float64
# marketing_click_rate      float64
# survey_response            object
# ...

# %%
df.head()
# Out:
#   Customer-ID  gender  age     country      city customer_segment  \
# 0  CUST_00001    Male   68  Bangladesh    London              SME
# 1  CUST_00002  Female   57      Canada    Sydney       Individual
# 2  CUST_00003    Male   24     Germany  New York              SME
# 3  CUST_00004    Male   49   Australia     Dhaka       Individual
# 4  CUST_00005    Male   65  Bangladesh     Delhi       Individual
#
#    tenure_months signup_channel contract_type  monthly_logins  ...  \
# 0             22            Web       Monthly              26  ...
# 1              9         Mobile       Monthly               7  ...
# 2             58            Web        Yearly              19  ...
# 3             19         Mobile        Yearly              34  ...
# 4             52            Web       Monthly              20  ...
#
#    price_increase_last_3m  avg_resolution_time  complaint_type  csat_score  \
# 0                      No            13.354360         Service         4.0
# ...

# %%
df1 = pd.DataFrame({'Key':['A','B','C'],'Value1':[1,2,3]})
df2 = pd.DataFrame({'Key':['A','B','D'],'Value2':[4,5,6]})

# %%
df1
# Out:
#   Key  Value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2
# Out:
#   Key  Value2
# 0   A       4
# 1   B       5
# 2   D       6

# %%
pd.merge(df1,df2,on="Key",how="inner")
# Out:
#   Key  Value1  Value2
# 0   A       1       4
# 1   B       2       5

# %%
df3 = pd.merge(df1,df2,on="Key",how="outer")

# %%
df3
# Out:
#   Key  Value1  Value2
# 0   A     1.0     4.0
# 1   B     2.0     5.0
# 2   C     3.0     NaN
# 3   D     NaN     6.0

# %%
df_final = df3.fillna("Unknown")
df_final
# Out:
#   Key   Value1   Value2
# 0   A      1.0      4.0
# 1   B      2.0      5.0
# 2   C      3.0  Unknown
# 3   D  Unknown      6.0

# %%
# !pip install lxml

# %%
# !pip install html5lib

# %%
# !pip install beautifulsoup4

# %%
url = "https://www.fdic.gov/bank-failures/failed-bank-list"
df = pd.read_html(url)

# %%
df[0]
# Out:
#                                             Bank Name                City  \
# 0                        The Santa Anna National Bank          Santa Anna
# 1                                Pulaski Savings Bank             Chicago
# 2                  The First National Bank of Lindsay             Lindsay
# 3               Republic First Bank dba Republic Bank        Philadelphia
# 4                                       Citizens Bank            Sac City
# 5                            Heartland Tri-State Bank             Elkhart
# 6                                 First Republic Bank       San Francisco
# 7                                      Signature Bank            New York
# 8                                 Silicon Valley Bank         Santa Clara
# 9                                   Almena State Bank              Almena
# 10                         First City Bank of Florida   Fort Walton Beach
# 11                               The First State Bank       Barboursville
# ...
